# %%
import numpy as np 
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Mean poverty rate of each state
# 1. Most common 15 Name or Surname of killed people
# 1. Killed People According to Races
# 1. Box and Swarm Plots in kill data
# 1. Kill properties (Count Plot)
#     * Number of people by gender
#     * Kill weapon
#     * Age of killed people
#     * Race of killed people
#     * Most dangerous cities
#     * Most dangerous states
#     * Having mental ilness or not for killed people
#     * Threat types
#     * Flee types
# <br>

# %%
pr = pd.read_csv('PercentagePeopleBelowPovertyLevel.csv', encoding="windows-1252")
sr = pd.read_csv('ShareRaceByCity.csv', encoding="windows-1252")
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %% [markdown]
# ## 1. Mean poverty rate of each state

# %%
pr.head()
# Out:
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
pr.poverty_rate.value_counts()
# Out:
# 0       1464
# -        201
# 7.4      129
# 6.7      129
# 10       128
#         ...
# 91.9       1
# 68         1
# 69.1       1
# 84.3       1
# 73.1       1
# Name: poverty_rate, Length: 771, dtype: int64

# %% [raw]
# Problem: We don't know what does "-" mean. We need to clean it. Maybe we can consider it as 0.

# %% [markdown]
# **INSTRUCTION-1: replace the "-" with zero.**

# %%
pr.poverty_rate.replace(['-'],0.0,inplace = True)

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29329 non-null  object
#  1   City             29329 non-null  object
#  2   poverty_rate     29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %% [raw]
# Problem: data type of poverty_rate colum is object. We need to convert it to a numeric type (float).

# %% [markdown]
# **INSTRUCTION-2 : Convert type of poverty_rate colum to a numeric type (float).**

# %%
pr.poverty_rate=pr.poverty_rate.astype("float")

# %%
pr.poverty_rate
# Out:
# 0        78.8
# 1        29.1
# 2        25.5
# 3        30.7
# 4        42.0
#          ...
# 29324    18.6
# 29325    15.3
# 29326     5.9
# 29327     5.4
# 29328     0.0
# Name: poverty_rate, Length: 29329, dtype: float64

# %% [markdown]
# **INSTRUCTION-3 : Plot the Poverty rate of each state. (Demonstrate mean value of each Geogrophic Area (AL, AK, AR).)**

# %%
pd.set_option('display.max_columns' ,None)

# %%
s=pr.groupby([pr["Geographic Area"]=="AK",pr["Geographic Area"]=="AL",pr["Geographic Area"]=="AR"])["poverty_rate"].mean()
s
# Out:
# Geographic Area  Geographic Area  Geographic Area
# False            False            False              16.082577
#                                   True               22.963216
#                  True             False              20.611795
# True             False            False              18.678592
# Name: poverty_rate, dtype: float64

# %% [markdown]
# **INSTRUCTION-3.a.1 : Plot With Pandas Built in method:**

# %%
k =pr.groupby("Geographic Area")["poverty_rate"].mean()
k.plot(kind="bar",figsize=(15,10),title="Poverty Rate Given States",x= "States",y = "poverty rate",legend=True,rot=45)
plt.xlabel("States")
plt.ylabel("Poverty Rate");

# %% [markdown]
# **INSTRUCTION-3.a.2 : Plot Sorted Values With Pandas Built in method:**

# %%
k.sort_values(ascending=False).plot(kind="bar",figsize=(13,9),title="Poverty Rate Given States",x= "States",y = "poverty rate");

# %% [markdown]
# **INSTRUCTION-3.b : Plot Sorted Values With Matplotlib:**

# %%
val = pr.groupby("Geographic Area")["poverty_rate"].mean().sort_values(ascending=False)
fig = plt.figure(figsize=(12,6))
ax = fig.add_axes([0,0,1,1])
ax.bar(x=val.index,height=val.values)
ax.set_xlabel("States")
ax.set_ylabel("Poverty Rate")
ax.set_title("Poverty Rate Given States")
plt.xticks(val.index,rotation=45);

# %% [markdown]
# **INSTRUCTION-3.c : Plot Sorted Values With Seaborn**

# %%
plt.figure(figsize=(14,9))
x= pr.groupby("Geographic Area")["poverty_rate"].mean().sort_values(ascending=False)
sns.barplot(x.index, x)  ;

# %% [markdown]
# ## 2. Most common 15 Name or Surname of killed people

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
kill.name.value_counts()
# Out:
# TK TK                     49
# Michael Johnson            2
# Brandon Jones              2
# TK Tk                      2
# Michael Brown              2
#                           ..
# Sean Michael Pelletier     1
# Denzel Brown               1
# Ramon Salazar              1
# Robert Dapkus              1
# Daniel Robert Avila        1
# Name: name, Length: 2481, dtype: int64

# %%
# Problem: TK TK is most probably not a name or surname. We will clean them.
pairs = kill.name[kill.name != 'TK TK'].str.split()
pairs.head()
# Out:
# 0             [Tim, Elliot]
# 1      [Lewis, Lee, Lembke]
# 2    [John, Paul, Quintero]
# 3        [Matthew, Hoffman]
# 4      [Michael, Rodriguez]
# Name: name, dtype: object

# %% [markdown]
# **INSTRUCTION : Plot Most common 15 Name or Surname of killed people**

# %% [raw]
# # Clue 1: You need to separate the names and surnames because we are asking most common name OR surname.
#
# # Clue 2 :After seperation make a whole list that contains both names and surnames.
#
# # Clue 3 : How to separate the name and surname pairs?
#
# >>> pairs = [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')]
# >>> numbers, letters = zip(*pairs)
# >>> numbers
# (1, 2, 3, 4)
# >>> letters
# ('a', 'b', 'c', 'd')
#
# # Clue 4: You can use Counter() and most_common() built in functions together to find the most common names or surnames, or you can write your functions for this purpose.

# %%
a = pairs.tolist()
a
# Out:
# [['Tim', 'Elliot'],
#  ['Lewis', 'Lee', 'Lembke'],
#  ['John', 'Paul', 'Quintero'],
#  ['Matthew', 'Hoffman'],
#  ['Michael', 'Rodriguez'],
#  ['Kenneth', 'Joe', 'Brown'],
#  ['Kenneth', 'Arnold', 'Buck'],
#  ['Brock', 'Nichols'],
#  ['Autumn', 'Steele'],
#  ['Leslie', 'Sapp', 'III'],
#  ['Patrick', 'Wetter'],
#  ['Ron', 'Sneed'],
#  ['Hashim', 'Hanif', 'Ibn', 'Abdul-Rasheed'],
#  ['Nicholas', 'Ryan', 'Brickman'],
#  ['Omarr', 'Julian', 'Maximillian', 'Jackson'],
#  ['Loren', 'Simpson'],
#  ['James', 'Dudley', 'Barker'],
#  ['Artago', 'Damon', 'Howard'],
#  ['Thomas', 'Hamby'],
#  ['Jimmy', 'Foreman'],
#  ['Andy', 'Martinez'],
#  ['Tommy', 'Smith'],
#  ['Brian', 'Barbosa'],
#  ['Salvador', 'Figueroa'],
#  ['John', 'Edward', "O'Keefe"],
#  ['Richard', 'McClendon'],
#  ['Marcus', 'Golden'],
#  ['Michael', 'Goebel'],
#  ['Mario', 'Jordan'],
#  ['Talbot', 'Schroeder'],
#  ['Robert', 'Edwards'],
#  ['Jeffrey', 'R.', 'Nielson'],
#  ['Donte', 'Sowell'],
#  ['Kavonda', 'Earl', 'Payton'],
#  ['Quincy', 'Reed', 'Reindl'],
#  ['Jose', 'Ceja'],
#  ['Nathan', 'Massey'],
#  ['Scott', 'Hall'],
#  ['Zaki', 'Shinwary'],
#  ['Terence', 'Walker'],
#  ['Pablo', 'Meza'],
#  ['Daniel', 'Brumley'],
#  ['Jonathan', 'Guillory'],
#  ['Carter', 'Castle'],
#  ['Paul', 'Campbell'],
#  ['Dewayne', 'Carr'],
#  ['Todd', 'Allen', 'Hodge'],
#  ['Miguel', 'Angel', 'de', 'Santos-Rodriguez'],
#  ['Isaac', 'Holmes'],
#  ['Andrew', 'Toto'],
#  ['Tiano', 'Meton'],
#  ['Kristiana', 'Coignard'],
#  ['Robert', 'Francis', 'Mesch'],
#  ['Demaris', 'Turner'],
#  ['Jose', 'Antonio', 'Espinoza', 'Ruiz'],
#  ['Wendell', 'King'],
#  ['Daryl', 'Myler'],
#  ['Darin', 'Hutchins'],
#  ['Orlando', 'Jude', 'Lopez'],
#  ['William', 'Campbell'],
#  ['Jessie', 'Hernandez'],
#  ['Raymond', 'Kmetz'],
#  ['Joshua', 'Omar', 'Garcia'],
#  ['David', 'Garcia'],
#  ['Nicolas', 'Leland', 'Tewa'],
#  ['Chris', 'Ingram'],
#  ['Jermonte', 'Fletcher'],
#  ['Tiffany', 'Terry'],
#  ['Alan', 'Lance', 'Alverson'],
#  ['Matautu', 'Nuu'],
#  ['Cody', 'Karasek'],
#  ['Ralph', 'Willis'],
#  ['Alan', 'James'],
#  ['John', 'Barry', 'Marshall'],
#  ['Victor', 'Manuel', 'Reyes'],
#  ['Edward', 'Donnell', 'Bright'],
#  ['Jacob', 'Haglund'],
#  ['David', 'Kassick'],
#  ['Francis', 'Murphy', 'Rose', 'III'],
#  ['Ledarius', 'D.', 'Williams'],
#  ['Yuvette', 'Henderson'],
#  ['Dewayne', 'Deshawn', 'Ward'],
#  ['Anthony', 'Purvis'],
#  ['Jeremy', 'Lett'],
#  ['Izzy', 'Colon'],
#  ['Salvador', 'Muna'],
#  ['Joaquin', 'Hernandez'],
#  ['Jimmy', 'Ray', 'Robinson', 'Jr.'],
#  ['Markell', 'Atkins'],
#  ['Paul', 'Alfred', 'Eugene', 'Johnson'],
#  ['Herbert', 'Hill'],
#  ['John', 'Sawyer'],
#  ['James', 'Allen'],
#  ['John', 'Martin', 'Whittaker'],
#  ['Sawyer', 'Flache'],
#  ['Vincent', 'Cordaro'],
#  ['Joseph', 'Paffen'],
#  ['Larry', 'Hostetter'],
#  ['Kenneth', 'Kreyssig'],
#  ['Desmond', 'Luster'],
#  ['Antonio', 'Zambrano-Montes'],
#  ['Anthony', 'Bess'],
#  ['Brian', 'Fritze'],
#  ['Phillip', 'Watkins'],
#  ['Fletcher', 'Ray', 'Stewart'],
#  ['Jonathan', 'Larry', 'Harden'],
#  ['Andres', 'Lara-Rodriguez'],
#  ['Richard', 'Carlin'],
#  ['Matthew', 'D.', 'Belk'],
#  ['Daniel', 'Mejia'],
#  ['Jason', 'C.', 'Hendrix'],
#  ['Roy', 'Joy', 'Day'],
#  ['Lavall', 'Hall'],
#  ['Howard', 'Brent', 'Means', 'Jr.'],
#  ['Bruce', 'Steward'],
#  ['Lawrence', 'Caldwell'],
#  ['Michael', 'K.', 'Casper'],
#  ['Cody', 'Evans'],
#  ['Betty', 'Sexton'],
#  ['Michael', 'Ireland'],
#  ['Matthew', 'Lundy'],
#  ['Douglas', 'Sparks'],
#  ['Pedro', 'Juan', 'Saldivar'],
#  ['Janisha', 'Fonville'],
#  ['Alejandro', 'Salazar'],
#  ['Ruben', 'Villalpando'],
#  ['Stanley', 'Lamar', 'Grant'],
#  ['Douglas', 'Harris'],
#  ['Jason', 'Moncrief', 'Carter'],
#  ['Kent', 'Norman'],
#  ['Bradford', 'Leonard'],
#  ['Jerome', 'Nichols'],
#  ['Daniel', 'Elrod'],
#  ['Robert', 'Kohl'],
#  ['Michael', 'Wayne', 'Smashey'],
#  ['Anthony', 'Giaquinta'],
#  ["A'Donte", 'Washington'],
#  ['Joseph', 'Biegert'],
#  ['Glenn', 'Lewis'],
#  ['Francis', 'Spivey'],
#  ['Alexander', 'Phillip', 'Long'],
#  ['David', 'Cuevas'],
#  ['Amilcar', 'Perez-Lopez'],
#  ['Rodney', 'Biggs'],
#  ['Crystal', 'Lee', 'Miley', 'Harry'],
#  ['Ernesto', 'Javiar', 'Canepa', 'Diaz'],
#  ['Chazsten', 'Freeman'],
#  ['Deven', 'Guilford'],
#  ['Thomas', 'Allen'],
#  ['Jessica', 'Uribe'],
#  ['Cornelius', 'J.', 'Parker'],
#  ['Ian', 'Sherrod'],
#  ['Stephanie', 'Hill'],
#  ['Donald', 'Lewis', 'Matkins'],
#  ['Charly', 'Leundeu', 'Keunang'],
#  ['Hung', 'Trieu'],
#  ['Shaquille', 'Barrow'],
#  ['Fednel', 'Rhinvil'],
#  ['Matthew', 'Metz'],
#  ['Derek', 'Cruice'],
#  ['Carl', 'Lao'],
#  ['Tyrone', 'Ryerson', 'Lawrence'],
#  ['Sergio', 'Alexander', 'Navas'],
#  ['Tyson', 'Hubbard'],
#  ['Naeschylus', 'Vinzant'],
#  ['Andrew', 'Anthony', 'Williams'],
#  ['Tony', 'Robinson'],
#  ['Adam', 'Reinhart'],
#  ['Aurelio', 'Duarte'],
#  ['Michael', 'McKillop'],
#  ['Monique', 'Jenee', 'Deckard'],
#  ['Lester', 'Brown'],
#  ['James', 'Brent', 'Damon'],
#  ['Cedrick', 'Lamont', 'Bishop'],
#  ['Anthony', 'Hill'],
#  ['Jamie', 'Croom'],
#  ['Christopher', 'Mitchell'],
#  ['Edixon', 'Franco'],
#  ['Theodore', 'Johnson'],
#  ['James', 'Greenwell'],
#  ['Benito', 'Osorio'],
#  ['Ryan', 'Dean', 'Burgess'],
#  ['Aaron', 'Valdez'],
#  ['Gilbert', 'Fleury'],
#  ['William', 'Russell', 'Smith'],
#  ['Terry', 'Garnett', 'Jr.'],
#  ['Bobby', 'Gross'],
#  ['Fred', 'Liggett'],
#  ['Andrew', 'Driver'],
#  ['Antonio', 'Perez'],
#  ['James', 'Richard', 'Jimenez'],
#  ['Richard', 'Castilleja'],
#  ['Clifton', 'Reintzel'],
#  ['Aaron', 'Siler'],
#  ['Troy', 'Ray', 'Boyd'],
#  ['Justin', 'Tolkinen'],
#  ['William', 'Dean', 'Poole'],
#  ['Eugene', 'Smith'],
#  ['Roberto', 'Leon'],
#  ['Andrew', 'Charles', 'Shipley'],
#  ['Declan', 'Owen'],
#  ['Alice', 'Brown'],
#  ['Jeff', 'Alexander'],
#  ['Kaylene', 'Stone'],
#  ['Garland', 'Lee', 'Wingo'],
#  ['Kendre', 'Alston'],
#  ['Jamison', 'Childress'],
#  ['Robert', 'Burdge'],
#  ['Shane', 'Watkins'],
#  ['Brandon', 'Jones'],
#  ['Brandon', 'Rapp'],
#  ['Justin', 'Fowler'],
#  ['Richard', 'White'],
#  ['Tyrel', 'Vick'],
#  ['James', 'Ellis'],
#  ['Gary', 'Page'],
#  ['Jason', 'Smith'],
#  ['Enoch', 'Gaver'],
#  ['Phillip', 'Conley'],
#  ['Christopher', 'Ryan', 'Healy'],
#  ['Denzel', 'Brown'],
#  ['Devin', 'Gates'],
#  ['Stephen', 'Snyder'],
#  ['Walter', 'J.', 'Brown', 'III'],
#  ['Scott', 'Dunham'],
#  ['Nicholas', 'Thomas'],
#  ['Jeremy', 'Lorenza', 'Kelly'],
#  ['Victor', 'Terrazas'],
#  ['Joseph', 'Tassinari'],
#  ['Deanne', 'Choate'],
#  ['Adrian', 'Solis'],
#  ['Gary', 'Kendrick'],
#  ['Jamalis', 'Hall'],
#  ['Adrian', 'Hernandez'],
#  ['Neil', 'Seifert'],
#  ['Megan', 'Hockaday'],
#  ['Harvey', 'Oates'],
#  ['Angelo', 'West'],
#  ['Robert', 'Rooker'],
#  ['Byron', 'Herbert'],
#  ['Brian', 'Babb'],
#  ['John', 'Marcell', 'Allen'],
#  ['Jeremy', 'Anderson'],
#  ['Benjamin', 'Quezada'],
#  ['Mya', 'Hall'],
#  ['Robert', 'Washington'],
#  ['Shawn', 'Clyde'],
#  ['Darrin', 'Langford'],
#  ['Donald', 'Hicks'],
#  ['Eric', 'Harris'],
#  ['Aaron', 'Rutledge'],
#  ['Christopher', 'Prevatt'],
#  ['Justus', 'Howell'],
#  ['Walter', 'Scott'],
#  ['Paul', 'Anderson'],
#  ['Ethan', 'Noll'],
#  ['Ken', 'Cockerel'],
#  ['Richard', 'Hanna'],
#  ['Alexander', 'Myers'],
#  ['Desmond', 'Willis'],
#  ['Tyrell', 'J.', 'Larsen'],
#  ['Erick', 'Rose'],
#  ['Douglas', 'Faith'],
#  ['Dexter', 'Pernell', 'Bethea'],
#  ['Roberto', 'Rodriguez'],
#  ['Joseph', 'Jeremy', 'Weber'],
#  ['Mark', 'Smith'],
#  ['Gordon', 'Kimbrell'],
#  ['Don', 'Smith'],
#  ['Jess', 'Leipold'],
#  ['Phillip', 'Burgess'],
#  ['Angel', 'Cresencio', 'Corona'],
#  ['Richard', 'Reed'],
#  ['Donald', 'Allen'],
#  ['Mack', 'Long'],
#  ['Richard', 'Dale', 'Weaver'],
#  ['Jason', 'Lee', 'Evans'],
#  ['Isaac', 'Jimenez'],
#  ['Colby', 'Robinson'],
#  ['Christopher', 'Grant', 'Finley'],
#  ['Tevin', 'Barkley'],
#  ['Dante', 'Noble'],
#  ['Frank', 'Shephard'],
#  ['Mark', 'W.', 'Adair'],
#  ['Stanley', 'Watson'],
#  ['Ernesto', 'Flores'],
#  ['Rodolfo', 'Velazquez'],
#  ['Jeffrey', 'Kemp'],
#  ['Elias', 'Cavazos'],
#  ['Thaddeus', 'McCarroll'],
#  ['Erik', 'Tellez'],
#  ['Grover', 'Sapp'],
#  ['Michael', 'Foster'],
#  ['Dana', 'Hlavinka'],
#  ['Santos', 'Cortez', 'Hernandez'],
#  ['Daniel', 'Wolfe'],
#  ['Daniel', 'Covarrubias'],
#  ['Kimber', 'Key'],
#  ['Luis', 'Martinez'],
#  ['William', 'Chapman'],
#  ['Carlos', 'Saavedra', 'Ramirez'],
#  ['Jonathan', 'Efraim'],
#  ['Reginald', 'McGregor'],
#  ['Lue', 'Vang'],
#  ['Andrew', 'Valadez'],
#  ['Joseph', 'Potts'],
#  ['Hector', 'Morejon'],
#  ['Karen', 'Janks'],
#  ['Mark', 'Cecil', 'Hawkins'],
#  ['Gary', 'Timmie', 'Collins'],
#  ['Todd', 'Jamal', 'Dye'],
#  ['Brandon', 'Lawrence'],
#  ['David', 'Felix'],
#  ['Daniel', 'Davis'],
#  ['Billy', 'Joe', 'Patrick'],
#  ['Albert', 'Hanson'],
#  ['Dean', 'Genova'],
#  ['Terrance', 'Kellom'],
#  ['David', 'Parker'],
#  ['Jared', 'Johnson'],
#  ['Joshua', 'Green'],
#  ['Andrew', 'Jackson'],
#  ['Joshua', 'Deysie'],
#  ['Luis', 'Chavez-Diaz'],
#  ['Alexia', 'Christian'],
#  ['Jeffrey', 'Adkins'],
#  ['John', 'Acree'],
#  ['Fridoon', 'Zalbeg', 'Nehad'],
#  ['Erick', 'Emmanuel', 'Sanchez'],
#  ['Kenneth', 'Mathena'],
#  ['Kevin', 'Vance', 'Norton'],
#  ['Elton', 'Simpson'],
#  ['Nadir', 'Soofi'],
#  ['Billy', 'Grimm'],
#  ['Michael', 'Asher'],
#  ['Roark', 'Cook'],
#  ['Brendon', 'Glenn'],
#  ['Thong', 'Kien', 'Ma'],
#  ['Robert', 'A.', 'Frost'],
#  ['David', 'William', 'Johnson'],
#  ['Joseph', 'Roy'],
#  ['Michael', 'Murphy'],
#  ['Nephi', 'Arriguin'],
#  ['Shaun', 'Johnson'],
#  ['David', 'Schwalm'],
#  ['Dedrick', 'Marshall'],
#  ['Sam', 'Holmes'],
#  ['Stephen', 'Cunningham'],
#  ['Lionel', 'Lorenzo', 'Young'],
#  ['Kelvin', 'Goldston'],
#  ['Justin', 'Way'],
#  ["D'Angelo", 'Stallworth'],
#  ['Bruce', 'Zalonka'],
#  ['Alec', 'Ouzounian'],
#  ['Sean', 'Michael', 'Pelletier'],
#  ['Cary', 'Martin'],
#  ['Mark', 'Farrar'],
#  ['Matt', 'Coates'],
#  ['Ronell', 'Wade'],
#  ['Dennis', 'Fiel'],
#  ['Austin', 'Goodner'],
#  ['Timothy', 'Jones'],
#  ['Alfredo', 'Rials-Torres'],
#  ['Jonathan', 'McIntosh'],
#  ['David', 'Gaines'],
#  ['Anthony', 'Gomez'],
#  ['Jonathan', 'Colley'],
#  ['Chrislon', 'Talbott'],
#  ['Nikki', 'Jo', 'Burtsfield'],
#  ['Marcus', 'Wheeler'],
#  ['David', 'Alejandro', 'Gandara'],
#  ['Javoris', 'Washington'],
#  ['James', 'Anthony', 'Cooper'],
#  ['Elvin', 'Diaz'],
#  ['Jerome', 'Caldwell'],
#  ['Michael', 'Lowery'],
#  ['Caso', 'Jackson'],
#  ['James', 'Horn'],
#  ['Eric', 'Robinson'],
#  ['Cassandra', 'Bolin'],
#  ['Anthony', 'Briggs'],
#  ['Millard', 'Tallant', 'III'],
#  ['Dalton', 'Branch'],
#  ['Jessie', 'Williams'],
#  ['Scott', 'McAllister'],
#  ['Garrett', 'Sandeno'],
#  ['Harry', 'Davis'],
#  ['Feras', 'Morad'],
#  ['Simon', 'Hubble'],
#  ['Darrell', 'Morgan'],
#  ['James', 'Strong'],
#  ['Kenneth', 'Dothard'],
#  ['Kyle', 'Baker'],
#  ['Kevin', 'Allen'],
#  ['Nehemiah', 'Fischer'],
#  ['Robert', 'Box'],
#  ['Ebin', 'Lamont', 'Proctor'],
#  ['Alexander', 'Tirado', 'Rivera'],
#  ['James', 'Anthony', 'Morris'],
#  ['James', 'Bushey'],
#  ['Joseph', 'Ladd'],
#  ['Usaamah', 'Rahim'],
#  ['Kamal', 'Dajani'],
#  ['Lorenzo', 'Garza'],
#  ['Rudy', 'Baca'],
#  ['Miguel', 'Martinez'],
#  ['Edelmiro', 'Hernandez'],
#  ['Ronald', 'Neal'],
#  ['Jesus', 'Quezada', 'Gomez'],
#  ['Christie', 'Cathers'],
#  ['Demouria', 'Hogg'],
#  ['James', 'Smillie'],
#  ['Alejandro', 'Campos', 'Fernandez'],
#  ['Joe', 'Nevels'],
#  ['Damien', 'Ramirez'],
#  ['Matthew', 'Wayne', 'McDaniel'],
#  ['Gene', 'Marshall'],
#  ['James', 'Johnson'],
#  ['Rene', 'Garcia'],
#  ['Richard', 'Warolf'],
#  ['Jeremy', 'Linhart'],
#  ['Greg', 'Hartley'],
#  ['QuanDavier', 'Hicks'],
#  ['Ryan', 'Bolinger'],
#  ['Isiah', 'Hampton'],
#  ['Charles', 'Ziegler'],
#  ['Raymond', 'Phillips'],
#  ['Fritz', 'Severe'],
#  ['Mark', 'Flores'],
#  ['Raymond', 'Peralta-Lantigua'],
#  ['Shelly', 'Haendiges'],
#  ['Anthony', 'Hodge'],
#  ['Deng', 'Manyoun'],
#  ['James', 'Boulware'],
#  ['Kenneth', 'Garcia'],
#  ['Zane', 'Terryn'],
#  ['Kris', 'Jackson'],
#  ['Christopher', 'DeLeon'],
#  ['Joe', 'Charboneau'],
#  ['Wendy', 'Chappell'],
#  ['Kenneth', 'Lanphier'],
#  ['Oleg', 'Tcherniak'],
#  ['Santos', 'Laboy'],
#  ['Trepierre', 'Hummons'],
#  ['Louis', 'Atencio'],
#  ['Alfontish', 'Cockerham'],
#  ['Adrian', 'Simental'],
#  ['Charles', 'Marshall'],
#  ['James', 'Monroe', 'Barrett'],
#  ['Eduardo', 'Reyes'],
#  ['Tyler', 'Wicks'],
#  ['Tyrone', 'Harris'],
#  ['Joshua', 'Dyer'],
#  ['Jonathan', 'Wilson'],
#  ['Randall', 'Waddel'],
#  ['Taylor', 'Culbertson'],
#  ['Damien', 'A.', 'Harrell'],
#  ['Spencer', 'McCain'],
#  ['Gilbert', 'Jake', 'Vanderburgh'],
#  ['Richard', 'Matt'],
#  ['Joe', 'Angel', 'Cisneros'],
#  ['Joshua', 'Crittenden'],
#  ['Alan', 'Bellew'],
#  ['Richard', 'LaPort'],
#  ['Clay', 'Alan', 'Lickteig'],
#  ['Kevin', 'Lamont', 'Judson'],
#  ['Kaleb', 'Landon'],
#  ['Douglas', 'Buckley'],
#  ['Ton', 'Nguyen'],
#  ['Victor', 'Emanuel', 'Larosa'],
#  ['Brian', 'Johnson'],
#  ['Cesar', 'A.', 'Limon', 'Juarez'],
#  ['Arturo', 'Lopez'],
#  ['Oscar', 'Camacho'],
#  ['Joseph', 'Julian'],
#  ['Robert', 'Elando', 'Malone'],
#  ['Michael', 'Shannon', 'Gaby'],
#  ['Kawanza', 'Beaty'],
#  ['Bryan', 'David', 'Bauer'],
#  ['John', 'Deming'],
#  ['Michael', 'Holt'],
#  ['Richard', 'Munroe'],
#  ['Johnny', 'Ray', 'Anderson'],
#  ['Tyler', 'Rogers'],
#  ['Hagen', 'Esty-Lennon'],
#  ['David', 'Oliva', 'Sarabia'],
#  ['John', 'Leonard', 'Berry'],
#  ['Jason', 'Hendley'],
#  ['Marcellus', 'Jamarcus', 'Burley'],
#  ['Adam', 'Dujanovic'],
#  ['Joe', 'Cody'],
#  ['Daniel', 'Hernandez'],
#  ['Jose', 'Graciano', 'Lopez'],
#  ['Tremaine', 'Dantzler'],
#  ['Nicholas', 'Booth'],
#  ['Joshua', 'Blough'],
#  ['Michael', 'Terence', 'Westrich'],
#  ['Dallas', 'Shatley'],
#  ['Rocco', 'Joseph', 'Palmisano'],
#  ['Robert', 'Hammonds'],
#  ['Martice', 'Milliner'],
#  ['Cyrus', 'Hurtado'],
#  ['Neil', 'White'],
#  ['Javon', 'Hawkins'],
#  ['James', 'Michael', 'Todora'],
#  ['Freddie', 'Blue'],
#  ['Eugene', 'McSwain'],
#  ['Billy', 'Maine'],
#  ['Paul', 'Castaway'],
#  ['Salvado', 'Ellswood'],
#  ['David', 'Lepine'],
#  ['Matthew', 'Watson'],
#  ['Christopher', 'Benton'],
#  ['Frederick', 'Farmer'],
#  ['Matthew', 'Ryan', 'Graham'],
#  ['Rafael', 'Suazo'],
#  ['Jason', 'Davis'],
#  ['Chacarion', 'Avant'],
#  ['Charles', 'Crandall'],
#  ['Eugene', 'Kailing'],
#  ['Anthonie', 'Smith'],
#  ['Antonio', 'Gonzalez'],
#  ['Edward', 'Foster', 'III'],
#  ['Patrick', 'Stephen', 'Pippin'],
#  ['Mohammad', 'Youssef', 'Abdulazeez'],
#  ['Saige', 'Hack'],
#  ['Pierre', 'Gabriel', 'Koellner'],
#  ['Samuel', 'Smith'],
#  ['Albert', 'Joseph', 'Davis'],
#  ['Jackie', 'Brand'],
#  ['Darrius', 'Stewart'],
#  ['Jose', 'Roman', 'Rodriguez'],
#  ['David', 'Wheat', 'Jr.'],
#  ['Kevin', 'Thomas', 'Snyder'],
#  ['Charles', 'Edward', 'Dewey'],
#  ['Samuel', 'DuBose'],
#  ['Joshua', 'LeBoeuf'],
#  ['Troy', 'Francis'],
#  ['Darren', 'Billy', 'Wilson'],
#  ['Joseph', 'Fuller'],
#  ['Jerrod', 'Tyre'],
#  ['Francisco', 'Benitez-Santiago'],
#  ['Andre', 'Dontrell', 'Williams'],
#  ['Devon', 'Guisherd'],
#  ['Dontae', 'L.', 'Martin'],
#  ['Derek', 'Wolfsteller'],
#  ['Brian', 'Stortzum'],
#  ['Robbie', 'Lee', 'Edison'],
#  ['Tamala', 'Satre'],
#  ['Seth', 'Raines'],
#  ['Lee', 'Aaron', 'Gerston'],
#  ['Christopher', 'Olmstead'],
#  ['Roger', 'Braswell'],
#  ['Bryan', 'Keith', 'Day'],
#  ['Earl', 'Jackson'],
#  ['Khari', 'Westly'],
#  ['Zachary', 'Hammond'],
#  ['Timothy', 'Milliken'],
#  ['Jean', 'Paul', 'Falgout'],
#  ['Samuel', 'Forgy'],
#  ['Timothy', 'Johnson'],
#  ['Michael', 'Malone'],
#  ['Roger', 'Darrin', 'Barker'],
#  ['Mark', 'Perkins'],
#  ['Ryan', 'Daniel', 'Vrenon'],
#  ['Philip', 'Vallejo'],
#  ['Oscar', 'Lotari', 'Romero'],
#  ['Rafael', 'Molina'],
#  ['Jeremy', 'Hatch'],
#  ['David', 'Cook'],
#  ['Armando', 'Serrano'],
#  ['Virgil', 'Reynolds'],
#  ['Antonio', 'Clements'],
#  ['Joshua', 'Malave'],
#  ['Franklin', 'Short'],
#  ['Shawn', 'Ruble'],
#  ['Daniel', 'Robert', 'Avila'],
#  ['Darius', 'D.', 'Graves'],
#  ['Tyler', 'Alexander', 'Dattilo'],
#  ['John', 'Dieringer'],
#  ['Raymond', 'Hodge'],
#  ['Keshawn', 'Dominique', 'Hargrove'],
#  ['Vincente', 'Montano'],
#  ['Jason', 'Galaviz'],
#  ['Gustavo', 'Ponce-Galon'],
#  ['Charles', 'Bertram'],
#  ['Christian', 'Taylor'],
#  ['Abel', 'Correa'],
#  ['Aaron', 'Marchese'],
#  ['Mark', 'Keckhafer'],
#  ['Tsombe', 'Clark'],
#  ['Derrick', 'Lee', 'Hunt'],
#  ['Roderick', 'Burr'],
#  ['Shamir', 'Terrel', 'Palmer'],
#  ['Jeffrey', 'Clyde', 'Wilkes'],
#  ['Kevin', 'McDaniel'],
#  ['Andre', 'Green'],
#  ['Eric', 'Tompkins'],
#  ['Robert', 'Patrick', 'Quinn'],
#  ['Edrian', 'Rivera'],
#  ['Richard', 'Tyler', 'Young'],
#  ['Casey', 'George', 'Alarcon'],
#  ['Randall', 'Lance', 'Hughes'],
#  ['Richard', 'Dean', 'Shull', 'Jr.'],
#  ['Nathaniel', 'Wilks'],
#  ['Redel', 'Jones'],
#  ['Anthony', 'Lorenzo', 'Vallejo'],
#  ['Reginald', 'Marshall'],
#  ['William', 'Smith'],
#  ['Garland', 'Tyree'],
#  ['Hector', 'Rene', 'Sorriano', 'Gonzalez'],
#  ['Asshams', 'Pharoah', 'Manley'],
#  ['Christopher', 'Anderson'],
#  ['John', 'Unsworth'],
#  ['Allen', 'Matthew', 'Baker'],
#  ['Benjamin', 'Peter', 'Ashley'],
#  ['Jonathon', 'Pope'],
#  ['Matthew', 'Castillo'],
#  ['Steven', 'B.', 'Norton'],
#  ['Frederick', 'Roy'],
#  ['Richard', 'Jacquez'],
#  ['Mansur', 'Ball-Bey'],
#  ['Deviere', 'Ernel', 'Ransom'],
#  ['Jason', 'Hale'],
#  ['Wade', 'Allen', 'Baker'],
#  ['Tyler', 'Gerken'],
#  ['Jeffory', 'Ray', 'Tevis'],
#  ['Raul', 'Herrera'],
#  ['Timmy', 'Walling'],
#  ['Charles', 'S.', 'Hall'],
#  ['Alan', 'Joseph', 'Rushton'],
#  ['Adam', 'Schneider'],
#  ['Thaddeus', 'Faison'],
#  ['Jason', 'Lee', 'Alderman'],
#  ['Nicholas', 'Garner'],
#  ['Kenneth', 'Henry', 'Morgan'],
#  ['Richard', 'Francis', 'Compo'],
#  ['Christopher', 'Ray', 'Tompkins'],
#  ['Julian', 'Hoffman'],
#  ['Bobby', 'Troledge', 'Norris'],
#  ['William', 'Lee', 'Snider'],
#  ['Marvin', 'Maestas'],
#  ['Curtis', 'Smith'],
#  ['Todd', 'Tomlinson'],
#  ['Shane', 'Rudolph'],
#  ['Marvin', 'Arroliga'],
#  ['Steven', 'Dodd'],
#  ['Brent', 'Pickard'],
#  ['Kyle', 'Lambrose'],
#  ['Bertrand', 'Davis'],
#  ['Yonas', 'Alehegne'],
#  ['Robert', 'Hober'],
#  ['Manuel', 'Soriano'],
#  ['Gilbert', 'Flores'],
#  ['William', 'Evans'],
#  ['Felix', 'Kumi'],
#  ['Devin', 'Brian', 'Dial'],
#  ['James', 'Marcus', 'Brown'],
#  ['Roger', 'Albrecht'],
#  ['Rafael', 'Cruz', 'Jr'],
#  ['Shawn', 'Hall'],
#  ['David', 'M.', 'Leon'],
#  ['William', 'Rippley'],
#  ['Cedric', 'Maurice', 'Williams'],
#  ['Charles', 'Robert', 'Shaw'],
#  ['Michael', 'Todd', 'Evans'],
#  ['Arthur', 'Bates'],
#  ['Freddy', 'Centeno'],
#  ['Curtis', 'James', 'Meyer'],
#  ['Jose', 'Ramon', 'Damiani', 'Jr'],
#  ['Richard', 'Keith', 'Kelley'],
#  ['Sully', 'Lanier'],
#  ['Harrison', 'Lambert'],
#  ["La'vante", 'Trevon', 'Biggs'],
#  ['Luis', 'Wenceslao'],
#  ['Angelo', 'Delano', 'Perry'],
#  ['India', 'Kager'],
#  ['Carlos', 'Yero'],
#  ['Mohamed', 'Ibrahim'],
#  ['William', 'Verrett'],
#  ['Casimero', 'Carlos', 'Casillas'],
#  ['Tristan', 'Vent'],
#  ['Dustin', 'Kuik'],
#  ['Tyrone', 'Holman'],
#  ['Vincent', 'J.', 'Perdue'],
#  ['William', 'Chau'],
#  ['Tian', 'Ma'],
#  ['Bruce', 'Santino'],
#  ['Brandon', 'Foy'],
#  ['Austin', 'Wilburly', 'Reid'],
#  ['Eddie', 'Tapia'],
#  ['Robert', 'T.', 'Edwards'],
#  ['Phillip', 'Pfleghardt'],
#  ['Derick', 'Davis'],
#  ['Jack', 'Stevens', 'Jr.'],
#  ['Martin', 'Francis', 'Hammen'],
#  ['Clifford', 'Butler'],
#  ['Jeffrey', 'Eugene', 'Brooks'],
#  ['Joseph', 'Thompson', 'Johnson-Shanks'],
#  ['David', 'Todd', 'Powell'],
#  ['Tyrone', 'Bass'],
#  ['Florencio', 'Chaidez'],
#  ['Jorge', 'Suarez-Ruiz'],
#  ['Carlos', 'Wilhelm'],
#  ['Bobby', 'R.', 'Anderson'],
#  ['Rory', 'Lynn', 'Gunderman'],
#  ['Mark', 'Gary'],
#  ['Lawrence', 'Price'],
#  ['Nicholas', 'Alan', 'Johnson'],
#  ['Gregory', 'Herrell'],
#  ['Lucien', 'Rolland'],
#  ['Scott', 'Beech'],
#  ['Michael', 'Thomas', 'Pierce'],
#  ['Jerrald', 'Wright'],
#  ['Gerardo', 'Ramirez'],
#  ['William', 'Spaits'],
#  ['Tina', 'Money'],
#  ['Steven', 'McKenny'],
#  ['Timothy', 'Wagner'],
#  ['Dominic', 'Fuller'],
#  ['Dante', 'Osborne'],
#  ['Joel', 'Dixon', 'Smith'],
#  ['Tim', 'Kyle', 'Torngren'],
#  ['Donaven', 'Kyle', 'Anderson'],
#  ['Robert', 'Berger'],
#  ['Joseph', 'Khammash'],
#  ['Keith', 'Harrison', 'McLeod'],
#  ['Kenneth', 'Ray', 'Pinter'],
#  ['Jeremy', 'McDole'],
#  ['Ernesto', 'Medina', 'Lopez'],
#  ['Patrick', "O'Grady"],
#  ['Philip', 'Quinn'],
#  ['William', 'Lemmon'],
#  ['James', 'Anderson'],
#  ['Jeffrey', 'Blood'],
#  ['Anthony', 'McKinney'],
#  ['Alejandro', 'Lerma'],
#  ['Norma', 'Angelica', 'Guzman'],
#  ['Christopher', 'Shell'],
#  ['Victor', 'Oswaldo', 'Coronado-Martinez'],
#  ['Junior', 'Prosper'],
#  ['Alberto', 'Hernandez'],
#  ['Patrick', 'Stephen', 'Lundstrom'],
#  ['Robert', 'Christen'],
#  ['Brandon', 'Lamar', 'Johnson'],
#  ['David', 'M.', 'Diaz'],
#  ['Christian', 'Pena'],
#  ['Phyllis', 'Ilene', 'Jepsen'],
#  ['Matthew', 'Dobbins'],
#  ['James', 'Joseph', 'Byrd'],
#  ['Eric', 'Edgell'],
#  ['Jeffery', 'McCallum'],
#  ['James', 'Dunaway'],
#  ['Rodney', 'Jencsik'],
#  ['Omar', 'Ali'],
#  ['Charles', 'A.', 'Pettit'],
#  ['Donald', 'Miller', 'II'],
#  ['Amado', 'Lago'],
#  ['Gary', 'Carmona', 'Boitano'],
#  ['Margaret', 'Wagner'],
#  ['Christopher', 'Whitmarsh'],
#  ['Richard', 'Love'],
#  ['William', 'Combs'],
#  ['Travis', 'Quay'],
#  ['Anthony', 'Aguilar'],
#  ['Joe', 'Pasquez', 'Ortiz'],
#  ['Kevin', 'Lau'],
#  ['Bernard', 'Brandon', 'Powers'],
#  ['Robert', 'Humberto', 'Medellin'],
#  ['Jason', 'Day'],
#  ['Rudolph', 'Smith'],
#  ['Brent', 'Brannon'],
#  ['Michelle', 'Marie', 'Burg'],
#  ['Samuel', 'Villarreal'],
#  ['Michael', 'Donald', 'Clark'],
#  ['Leslie', 'Portis'],
#  ['Jorge', 'Santiago', 'Tapia'],
#  ['Kaleb', 'Alexander'],
#  ['Linda', 'Lee', 'Lush'],
#  ['Michael', 'J.', 'Brennan'],
#  ['Robert', 'Burgess'],
#  ['Herbert', 'Benitez'],
#  ['Martin', 'Ryans', 'Jr.'],
#  ['Johnny', 'Angel', 'Rangel'],
#  ['Jason', 'Foreman'],
#  ['Ricky', 'Javenta', 'Ball'],
#  ['Gino', 'Paredes'],
#  ['Dequan', 'Williams'],
#  ['Corey', 'Jones'],
#  ['Krikor', 'Ekizian'],
#  ['Dion', 'Lamont', 'Ramirez'],
#  ['Roger', 'D.', 'Hall'],
#  ['Lamontez', 'Jones'],
#  ['Joel', 'Lopes'],
#  ['Darien', 'Greenwood'],
#  ['Jonathan', 'Tyler', 'Gossman'],
#  ['Miguel', 'Angel', 'Marin', 'Galena'],
#  ['Ryan', 'Christopher', 'Rodriguez'],
#  ['Timothy', 'Arnold'],
#  ['Lawrence', 'Green'],
#  ['Adriene', 'Jamarr', 'Ludd'],
#  ['Stephen', 'H.', 'Brock'],
#  ['John', 'Tozzi'],
#  ['Juan', 'Ulloa'],
#  ['Rolly', 'Thomas'],
#  ['Dominic', 'Hutchinson'],
#  ['Arthur', 'West'],
#  ['Darren', 'Myron', 'Fude'],
#  ['Jon', 'Ployhar'],
#  ['John', 'Harley', 'Turner'],
#  ['Kevin', 'Brunson'],
#  ['Marquesha', 'McMillan'],
#  ['Kobvey', 'Igbuhay'],
#  ['Tyrie', 'Cuyler'],
#  ['Anthony', 'Ashford'],
#  ['Ricky', 'Keith', 'Keeton'],
#  ['Jerry', 'Michael', 'Graham', 'Jr.'],
#  ['Jasper', 'Levi', 'Adams'],
#  ['Deaunte', 'Lamar', 'Bell'],
#  ['Allen', 'Quintez', 'Swader'],
#  ['Floyd', 'Ray', 'Cook'],
#  ['Mario', 'Martinez'],
#  ['Tony', 'Berry'],
#  ['Daniel', 'Nole'],
#  ['Noah', 'Harpham'],
#  ['Bennie', 'Lee', 'Tignor'],
#  ['Luverne', 'Roy', 'Christensen'],
#  ['Killian', "O'Quinn"],
#  ['Jack', 'Yantis'],
#  ['James', 'Covington'],
#  ['Jeremy', 'Mardis'],
#  ['Joseph', 'Tyndall'],
#  ['John', 'Allen'],
#  ['Faisal', 'Mohammad'],
#  ['Timothy', 'Gene', 'Smith'],
#  ['David', 'Romanoski'],
#  ['James', 'Bigley'],
#  ['Jacob', 'Hohman'],
#  ['Laura', 'Lemieux'],
#  ['Michael', 'Johnson'],
#  ['James', 'Francis', 'Smyth'],
#  ['Kim', 'Lee', 'Long'],
#  ['Delvin', 'Simmons'],
#  ['Cesar', 'Cuellar'],
#  ['Dale', 'Maverick', 'Hudson'],
#  ['Leonel', 'Acevedo'],
#  ['Miguel', 'Cano'],
#  ['Dana', 'Bruce', 'Ott'],
#  ['Eddie', 'Gabriel', 'Sanchez'],
#  ['Jason', 'Leanard', 'Mesaros'],
#  ['Andrew', 'Blake'],
#  ['Joseph', 'Jaramillo'],
#  ['Javier', 'Lopez', 'Garcia'],
#  ['Brian', 'Gavin'],
#  ['Ryan', 'Quinn', 'Martin'],
#  ['Moises', 'Nero'],
#  ['Michael', 'Joseph', 'Bartkiewicz'],
#  ['Ernesto', 'Gamino'],
#  ['Matthew', 'Coleman'],
#  ['Ramon', 'Salazar'],
#  ['Richard', 'Perkins'],
#  ['John', 'David', 'Livingston'],
#  ['Shane', 'Whitehead'],
#  ['Jamar', 'Clark'],
#  ['Cameron', 'Davis', 'Long'],
#  ['Brent', 'Noblitt'],
#  ['Michael', 'Tindall'],
#  ['Yohans', 'Leon'],
#  ['Demetrius', 'Bryant'],
#  ['Jeray', 'Chatham'],
#  ['Derry', 'Touchstone'],
#  ['Francis', 'Hartnett'],
#  ['Cornelius', 'Brown'],
#  ['Marcus', 'Meridy'],
#  ['Randy', 'Allen', 'Smith'],
#  ['Steve', 'Dormil'],
#  ['Darick', 'Napper'],
#  ['William', 'Tarrant'],
#  ['Nathaniel', 'Harris', 'Pickett'],
#  ['Chris', 'Nichols'],
#  ['James', 'Daniel', 'Hall'],
#  ['Matthew', 'Grows'],
#  ['Miguel', 'Angel', 'Martinez'],
#  ['Henry', 'Reyna'],
#  ['Barry', 'Kirk'],
#  ['Michael', 'Kirvelay'],
#  ['Thomas', 'Joseph', 'Mceniry'],
#  ['Freddy', 'Baez'],
#  ['Magnum', 'Edgar', 'Phillips'],
#  ['Douglas', 'R.', 'Slade'],
#  ['Somer', 'Speer'],
#  ['Andrew', 'Thomas'],
#  ['Rick', 'Gullickson'],
#  ['Kevin', 'Close'],
#  ['Justin', 'D.', 'McHenry'],
#  ['Lionel', 'Kerns'],
#  ['Ralph', 'Aguilar'],
#  ['Hugo', 'Fernando', 'Celio'],
#  ['Zachary', 'Grigsby'],
#  ['Tuan', 'Hoang'],
#  ['Darius', 'Smith'],
#  ['Fernando', 'Sauceda'],
#  ['Joshua', 'Jozefowicz'],
#  ['John', 'Anthony', 'Gonzalez'],
#  ['Phillip', 'Munoz'],
#  ['Tashfeen', 'Malik'],
#  ['Syed', 'Farook'],
#  ['Mario', 'Woods'],
#  ['Allen', 'Pacheco'],
#  ['Florencio', 'Lucero'],
#  ['Neil', 'Scott', 'Stretesky'],
#  ['Ivan', 'Krstic'],
#  ['Raymone', 'M.', 'Davis'],
#  ['Colten', 'Price', 'Marcellus'],
#  ['David', 'Winesett'],
#  ['Michael', 'L.', 'Funk'],
#  ['Sheilah', 'Huck'],
#  ['Juan', 'Perez'],
#  ['Raymond', 'Azevedo'],
#  ['Carlumandarlo', 'Zaramo'],
#  ['John', 'Alan', 'Britton'],
#  ['Miguel', 'Espinal'],
#  ['Derek', 'Stokes'],
#  ['Christopher', 'Higdon'],
#  ['Sammy', 'Monroe', 'Echols'],
#  ['Jason', 'Bryant'],
#  ['Charles', 'Edward', 'Rosemond'],
#  ['Thomas', 'Arthur', 'Gendreau'],
#  ['Steven', 'Wickert'],
#  ['Christopher', 'Goodlow'],
#  ['Javario', 'Shante', 'Eagle'],
#  ['Nicholas', 'Robertson'],
#  ['Jonathan', 'Wardlow'],
#  ['Andrew', 'Jospeh', 'Todd'],
#  ['Roy', 'Carreon'],
#  ['Efrain', 'Villanueva'],
#  ['Shirley', 'Weis'],
#  ['Ryan', 'McMillan'],
#  ['Nephi', 'Leiataua'],
#  ['Enrique', 'Gonzalez'],
#  ['Calvin', 'McKinnis'],
#  ['Jeffrey', 'Gene', 'Evans'],
#  ['Michael', 'Thomason'],
#  ['Brenda', 'Dean', 'Kimberling'],
#  ['Mharloun', 'Verdejo', 'Saycon'],
#  ['Hector', 'Alvarez'],
#  ['Roberto', 'Sanchez'],
#  ['Mark', 'Toney'],
#  ['Ronnie', 'Dubose', 'Carter'],
#  ['Bryant', 'Neil', 'Duncan'],
#  ['Douglas', 'Yon'],
#  ['Christopher', 'Fletcher'],
#  ['Erica', 'Lauro'],
#  ['Amos', 'Frerichs'],
#  ['Robert', 'L.', 'Martinez'],
#  ['Trayvon', 'Scruggs'],
#  ['Ruben', 'Jose', 'Herrera'],
#  ['Leroy', 'Browning'],
#  ['Mark', 'Ramirez'],
#  ['Guadalupe', 'Quiroz'],
#  ['Bobby', 'Daniels'],
#  ['Michael', 'Noel'],
#  ['Derek', 'DeGroat'],
#  ['Robert', 'L.', 'Teter'],
#  ['Chan', 'Leith'],
#  ['Brandon', 'Barsnick'],
#  ['Charles', 'Reynolds'],
#  ['Kenneth', 'Stephens'],
#  ['Michael', 'Hilber'],
#  ['Jose', 'Rodriguez'],
#  ['Kevin', 'Matthews'],
#  ['Schuylar', 'Gunning'],
#  ['Gregory', 'Sanders'],
#  ['Terrozza', 'Tyree', 'Griffin'],
#  ['Omar', 'Ventura'],
#  ['Daquan', 'Antonio', 'Westbrook'],
#  ['William', 'David', 'Raff'],
#  ['Lonnie', 'Niesen'],
#  ['Bettie', 'Jones'],
#  ['Quintonio', 'LeGrier'],
#  ['Gilbert', 'Heredia'],
#  ['Michael', 'Parker'],
#  ['Sean', 'Mould'],
#  ['Gayneaux', 'Paul', 'Trahan'],
#  ['Corey', 'Jason', 'Achstein'],
#  ['Siolosega', 'Velega-Nuufolau'],
#  ['Tien', 'Hua'],
#  ['Fred', 'Perez'],
#  ['John', 'Randell', 'Veach'],
#  ['Keith', 'Childress'],
#  ['Joshua', 'Sisson'],
#  ['Sean', "O'Brien"],
#  ['Lance', 'Light'],
#  ['Lonnie', 'Haskell', 'Powers'],
#  ['Germonta', 'Wallace'],
#  ['Eric', 'John', 'Senegal'],
#  ['Rodney', 'Turner'],
#  ['Joel', 'Anthony', 'Nelson'],
#  ['James', 'K.', 'Maher'],
#  ['Carlton', 'Antonio', 'Murphy'],
#  ...]

# %%
count = [j for i in a for j in i]
most = Counter(count).most_common(15)
most
# Out:
# [('Michael', 91),
#  ('James', 57),
#  ('David', 57),
#  ('Robert', 48),
#  ('Joseph', 48),
#  ('William', 47),
#  ('Daniel', 46),
#  ('John', 42),
#  ('Christopher', 40),
#  ('Lee', 38),
#  ('Smith', 36),
#  ('Richard', 36),
#  ('Anthony', 32),
#  ('Johnson', 32),
#  ('J.', 32)]

# %%
a = pairs.str.join(" ").tolist()
surname=[i.split()[-1] for i in a]

# %%
ad = [i.split()[:-1] for i in a]
name = pd.Series(ad)
counter = Counter(name.str.join(" "))
m_c_name=counter.most_common()
#name.str.join(" ").value_counts()
m_c_name
# Out:
# [('Michael', 47),
#  ('Joseph', 24),
#  ('David', 23),
#  ('Joshua', 23),
#  ('Robert', 22),
#  ('William', 22),
#  ('Christopher', 22),
#  ('Daniel', 20),
#  ('Richard', 19),
#  ('John', 18),
#  ('James', 18),
#  ('Matthew', 15),
#  ('Anthony', 15),
#  ('Jason', 13),
#  ('Charles', 13),
#  ('Jose', 12),
#  ('Brandon', 12),
#  ('Mark', 12),
#  ('Andrew', 11),
#  ('Nicholas', 11),
#  ('Raymond', 10),
#  ('Kenneth', 10),
#  ('Timothy', 10),
#  ('Jeremy', 9),
#  ('Brian', 8),
#  ('Scott', 8),
#  ('Paul', 8),
#  ('Phillip', 8),
#  ('Kevin', 8),
#  ('Steven', 8),
#  ('Thomas', 7),
#  ('Derek', 7),
#  ('Justin', 7),
#  ('Eric', 7),
#  ('Jeffrey', 7),
#  ('Dennis', 7),
#  ('Mario', 6),
#  ('Jonathan', 6),
#  ('Jacob', 6),
#  ('Bruce', 6),
#  ('Douglas', 6),
#  ('Stephen', 6),
#  ('Kyle', 6),
#  ('Ronald', 6),
#  ('Francisco', 6),
#  ('Travis', 6),
#  ('Patrick', 5),
#  ('Antonio', 5),
#  ('Rodney', 5),
#  ('Adam', 5),
#  ('Aaron', 5),
#  ('Fred', 5),
#  ('Shawn', 5),
#  ('Donald', 5),
#  ('Luis', 5),
#  ('Hector', 5),
#  ('Miguel', 5),
#  ('Ryan', 5),
#  ('Samuel', 5),
#  ('Earl', 5),
#  ('Carlos', 5),
#  ('Jorge', 5),
#  ('Gregory', 5),
#  ('Omar', 5),
#  ('Sergio', 5),
#  ('Peter', 5),
#  ('Dylan', 5),
#  ('Marcus', 4),
#  ('Nathan', 4),
#  ('Cody', 4),
#  ('Herbert', 4),
#  ('Jerome', 4),
#  ('Francis', 4),
#  ('Jamie', 4),
#  ('Gilbert', 4),
#  ('Bobby', 4),
#  ('Eugene', 4),
#  ('Jeff', 4),
#  ('Benjamin', 4),
#  ('Eduardo', 4),
#  ('Tyler', 4),
#  ('Tyrone', 4),
#  ('Roger', 4),
#  ('Philip', 4),
#  ('Christian', 4),
#  ('Marvin', 4),
#  ('Brent', 4),
#  ('Manuel', 4),
#  ('Dominic', 4),
#  ('Juan', 4),
#  ('Steve', 4),
#  ('Henry', 4),
#  ('Keith', 4),
#  ('Jordan', 4),
#  ('Christopher Michael', 4),
#  ('Jesus', 4),
#  ('Cameron', 4),
#  ('George', 4),
#  ('Pedro', 4),
#  ('Isaiah', 4),
#  ('Tommy', 3),
#  ('Salvador', 3),
#  ('Vincent', 3),
#  ('Desmond', 3),
#  ('Lawrence', 3),
#  ('Alejandro', 3),
#  ('Ruben', 3),
#  ('Carl', 3),
#  ('Roberto', 3),
#  ('Shane', 3),
#  ('Adrian', 3),
#  ('Alexander', 3),
#  ('Don', 3),
#  ('Ernesto', 3),
#  ('Albert', 3),
#  ('Joe', 3),
#  ('Oscar', 3),
#  ('Rafael', 3),
#  ('Zachary', 3),
#  ('Arthur', 3),
#  ('Tristan', 3),
#  ('Dustin', 3),
#  ('Eddie', 3),
#  ('Gerardo', 3),
#  ('Cesar', 3),
#  ('Ramon', 3),
#  ('Miguel Angel', 3),
#  ('Barry', 3),
#  ('Darius', 3),
#  ('Fernando', 3),
#  ('Robert L.', 3),
#  ('William David', 3),
#  ('Sean', 3),
#  ('Martin', 3),
#  ('Luke', 3),
#  ('Abraham', 3),
#  ('Robin', 3),
#  ('Terry', 3),
#  ('Edward', 3),
#  ('Bradley', 3),
#  ('Chad', 3),
#  ('Terrence', 3),
#  ('Jesse', 3),
#  ('Michael Anthony', 3),
#  ('Jimmy', 2),
#  ('Terence', 2),
#  ('Pablo', 2),
#  ('Isaac', 2),
#  ('Jessie', 2),
#  ('Chris', 2),
#  ('Ralph', 2),
#  ('Alan', 2),
#  ('Markell', 2),
#  ('Glenn', 2),
#  ('Jessica', 2),
#  ('Tony', 2),
#  ('Theodore', 2),
#  ('Clifton', 2),
#  ('Gary', 2),
#  ('Devin', 2),
#  ('Victor', 2),
#  ('Neil', 2),
#  ('Angelo', 2),
#  ('Walter', 2),
#  ('Jason Lee', 2),
#  ('Colby', 2),
#  ('Dante', 2),
#  ('Stanley', 2),
#  ('Elias', 2),
#  ('Thaddeus', 2),
#  ('Erik', 2),
#  ('Dana', 2),
#  ('Reginald', 2),
#  ('Dean', 2),
#  ('Billy', 2),
#  ('Nephi', 2),
#  ('Sam', 2),
#  ('Austin', 2),
#  ('James Anthony', 2),
#  ('Simon', 2),
#  ('Darrell', 2),
#  ('Gene', 2),
#  ('Greg', 2),
#  ('Shelly', 2),
#  ('Kris', 2),
#  ('Randall', 2),
#  ('Taylor', 2),
#  ('Spencer', 2),
#  ('Kaleb', 2),
#  ('Frederick', 2),
#  ('Patrick Stephen', 2),
#  ('Charles Edward', 2),
#  ('Troy', 2),
#  ('Jerrod', 2),
#  ('Devon', 2),
#  ('Armando', 2),
#  ('Gustavo', 2),
#  ('Andre', 2),
#  ('Raul', 2),
#  ('Todd', 2),
#  ('David M.', 2),
#  ('Freddy', 2),
#  ('Curtis James', 2),
#  ('India', 2),
#  ('Mohamed', 2),
#  ('Clifford', 2),
#  ('Florencio', 2),
#  ('Tina', 2),
#  ('Leslie', 2),
#  ('Corey', 2),
#  ('Joel', 2),
#  ('Jack', 2),
#  ('Moises', 2),
#  ('Michael Joseph', 2),
#  ('Demetrius', 2),
#  ('James Daniel', 2),
#  ('Lionel', 2),
#  ('Ivan', 2),
#  ('Michael L.', 2),
#  ('John Alan', 2),
#  ('Roy', 2),
#  ('Efrain', 2),
#  ('Calvin', 2),
#  ('Leroy', 2),
#  ('Guadalupe', 2),
#  ('Daquan Antonio', 2),
#  ('Lonnie', 2),
#  ('Eric John', 2),
#  ('Eric C.', 2),
#  ('David Jay', 2),
#  ('Herman', 2),
#  ('Willie', 2),
#  ('Alfred', 2),
#  ('Clarence', 2),
#  ('Cedric', 2),
#  ('Johnathan', 2),
#  ('John Wesley', 2),
#  ('William A.', 2),
#  ('Ronnie', 2),
#  ('Danny', 2),
#  ('Kisha', 2),
#  ('David Michael', 2),
#  ('Tyre', 2),
#  ('Marco', 2),
#  ('Angel', 2),
#  ('Melissa', 2),
#  ('Peter J.', 2),
#  ('Damon', 2),
#  ('Mark Daniel', 2),
#  ('Sean Ryan', 2),
#  ('Norman', 2),
#  ('TK', 2),
#  ('Russell', 2),
#  ('Josh', 2),
#  ('Randy', 2),
#  ('Alton', 2),
#  ('Jermaine', 2),
#  ('Bernard', 2),
#  ('Robert Lee', 2),
#  ('Melvin', 2),
#  ('Ricardo', 2),
#  ('Michelle', 2),
#  ('Juan Carlos', 2),
#  ('Jamal', 2),
#  ('Rodney L.', 2),
#  ('William D.', 2),
#  ('Jonathan David', 2),
#  ('Jose Gonzales', 2),
#  ('Jimmie', 2),
#  ('Tim', 1),
#  ('Lewis Lee', 1),
#  ('John Paul', 1),
#  ('Kenneth Joe', 1),
#  ('Kenneth Arnold', 1),
#  ('Brock', 1),
#  ('Autumn', 1),
#  ('Leslie Sapp', 1),
#  ('Ron', 1),
#  ('Hashim Hanif Ibn', 1),
#  ('Nicholas Ryan', 1),
#  ('Omarr Julian Maximillian', 1),
#  ('Loren', 1),
#  ('James Dudley', 1),
#  ('Artago Damon', 1),
#  ('Andy', 1),
#  ('John Edward', 1),
#  ('Talbot', 1),
#  ('Jeffrey R.', 1),
#  ('Donte', 1),
#  ('Kavonda Earl', 1),
#  ('Quincy Reed', 1),
#  ('Zaki', 1),
#  ('Carter', 1),
#  ('Dewayne', 1),
#  ('Todd Allen', 1),
#  ('Miguel Angel de', 1),
#  ('Tiano', 1),
#  ('Kristiana', 1),
#  ('Robert Francis', 1),
#  ('Demaris', 1),
#  ('Jose Antonio Espinoza', 1),
#  ('Wendell', 1),
#  ('Daryl', 1),
#  ('Darin', 1),
#  ('Orlando Jude', 1),
#  ('Joshua Omar', 1),
#  ('Nicolas Leland', 1),
#  ('Jermonte', 1),
#  ('Tiffany', 1),
#  ('Alan Lance', 1),
#  ('Matautu', 1),
#  ('John Barry', 1),
#  ('Victor Manuel', 1),
#  ('Edward Donnell', 1),
#  ('Francis Murphy Rose', 1),
#  ('Ledarius D.', 1),
#  ('Yuvette', 1),
#  ('Dewayne Deshawn', 1),
#  ('Izzy', 1),
#  ('Joaquin', 1),
#  ('Jimmy Ray Robinson', 1),
#  ('Paul Alfred Eugene', 1),
#  ('John Martin', 1),
#  ('Sawyer', 1),
#  ('Larry', 1),
#  ('Fletcher Ray', 1),
#  ('Jonathan Larry', 1),
#  ('Andres', 1),
#  ('Matthew D.', 1),
#  ('Jason C.', 1),
#  ('Roy Joy', 1),
#  ('Lavall', 1),
#  ('Howard Brent Means', 1),
#  ('Michael K.', 1),
#  ('Betty', 1),
#  ('Pedro Juan', 1),
#  ('Janisha', 1),
#  ('Stanley Lamar', 1),
#  ('Jason Moncrief', 1),
#  ('Kent', 1),
#  ('Bradford', 1),
#  ('Michael Wayne', 1),
#  ("A'Donte", 1),
#  ('Alexander Phillip', 1),
#  ('Amilcar', 1),
#  ('Crystal Lee Miley', 1),
#  ('Ernesto Javiar Canepa', 1),
#  ('Chazsten', 1),
#  ('Deven', 1),
#  ('Cornelius J.', 1),
#  ('Ian', 1),
#  ('Stephanie', 1),
#  ('Donald Lewis', 1),
#  ('Charly Leundeu', 1),
#  ('Hung', 1),
#  ('Shaquille', 1),
#  ('Fednel', 1),
#  ('Tyrone Ryerson', 1),
#  ('Sergio Alexander', 1),
#  ('Tyson', 1),
#  ('Naeschylus', 1),
#  ('Andrew Anthony', 1),
#  ('Aurelio', 1),
#  ('Monique Jenee', 1),
#  ('Lester', 1),
#  ('James Brent', 1),
#  ('Cedrick Lamont', 1),
#  ('Edixon', 1),
#  ('Benito', 1),
#  ('Ryan Dean', 1),
#  ('William Russell', 1),
#  ('Terry Garnett', 1),
#  ('James Richard', 1),
#  ('Troy Ray', 1),
#  ('William Dean', 1),
#  ('Andrew Charles', 1),
#  ('Declan', 1),
#  ('Alice', 1),
#  ('Kaylene', 1),
#  ('Garland Lee', 1),
#  ('Kendre', 1),
#  ('Jamison', 1),
#  ('Tyrel', 1),
#  ('Enoch', 1),
#  ('Christopher Ryan', 1),
#  ('Denzel', 1),
#  ('Walter J. Brown', 1),
#  ('Jeremy Lorenza', 1),
#  ('Deanne', 1),
#  ('Jamalis', 1),
#  ('Megan', 1),
#  ('Harvey', 1),
#  ('Byron', 1),
#  ('John Marcell', 1),
#  ('Mya', 1),
#  ('Darrin', 1),
#  ('Justus', 1),
#  ('Ethan', 1),
#  ('Ken', 1),
#  ('Tyrell J.', 1),
#  ('Erick', 1),
#  ('Dexter Pernell', 1),
#  ('Joseph Jeremy', 1),
#  ('Gordon', 1),
#  ('Jess', 1),
#  ('Angel Cresencio', 1),
#  ('Mack', 1),
#  ('Richard Dale', 1),
#  ('Christopher Grant', 1),
#  ('Tevin', 1),
#  ('Frank', 1),
#  ('Mark W.', 1),
#  ('Rodolfo', 1),
#  ('Grover', 1),
#  ('Santos Cortez', 1),
#  ('Kimber', 1),
#  ('Carlos Saavedra', 1),
#  ('Lue', 1),
#  ('Karen', 1),
#  ('Mark Cecil', 1),
#  ('Gary Timmie', 1),
#  ('Todd Jamal', 1),
#  ('Billy Joe', 1),
#  ('Terrance', 1),
#  ('Jared', 1),
#  ('Alexia', 1),
#  ('Fridoon Zalbeg', 1),
#  ('Erick Emmanuel', 1),
#  ('Kevin Vance', 1),
#  ('Elton', 1),
#  ('Nadir', 1),
#  ('Roark', 1),
#  ('Brendon', 1),
#  ('Thong Kien', 1),
#  ('Robert A.', 1),
#  ('David William', 1),
#  ('Shaun', 1),
#  ('Dedrick', 1),
#  ('Lionel Lorenzo', 1),
#  ('Kelvin', 1),
#  ("D'Angelo", 1),
#  ('Alec', 1),
#  ('Sean Michael', 1),
#  ('Cary', 1),
#  ('Matt', 1),
#  ('Ronell', 1),
#  ('Alfredo', 1),
#  ('Chrislon', 1),
#  ('Nikki Jo', 1),
#  ('David Alejandro', 1),
#  ('Javoris', 1),
#  ('Elvin', 1),
#  ('Caso', 1),
#  ('Cassandra', 1),
#  ('Millard Tallant', 1),
#  ('Dalton', 1),
#  ('Garrett', 1),
#  ('Harry', 1),
#  ('Feras', 1),
#  ('Nehemiah', 1),
#  ('Ebin Lamont', 1),
#  ('Alexander Tirado', 1),
#  ('Usaamah', 1),
#  ('Kamal', 1),
#  ('Lorenzo', 1),
#  ('Rudy', 1),
#  ('Edelmiro', 1),
#  ('Jesus Quezada', 1),
#  ('Christie', 1),
#  ('Demouria', 1),
#  ('Alejandro Campos', 1),
#  ('Damien', 1),
#  ('Matthew Wayne', 1),
#  ('Rene', 1),
#  ('QuanDavier', 1),
#  ('Isiah', 1),
#  ('Fritz', 1),
#  ('Deng', 1),
#  ('Zane', 1),
#  ('Wendy', 1),
#  ('Oleg', 1),
#  ('Santos', 1),
#  ('Trepierre', 1),
#  ('Louis', 1),
#  ('Alfontish', 1),
#  ('James Monroe', 1),
#  ('Damien A.', 1),
#  ('Gilbert Jake', 1),
#  ('Joe Angel', 1),
#  ('Clay Alan', 1),
#  ('Kevin Lamont', 1),
#  ('Ton', 1),
#  ('Victor Emanuel', 1),
#  ('Cesar A. Limon', 1),
#  ('Arturo', 1),
#  ('Robert Elando', 1),
#  ('Michael Shannon', 1),
#  ('Kawanza', 1),
#  ('Bryan David', 1),
#  ('Johnny Ray', 1),
#  ('Hagen', 1),
#  ('David Oliva', 1),
#  ('John Leonard', 1),
#  ('Marcellus Jamarcus', 1),
#  ('Jose Graciano', 1),
#  ('Tremaine', 1),
#  ('Michael Terence', 1),
#  ('Dallas', 1),
#  ('Rocco Joseph', 1),
#  ('Martice', 1),
#  ('Cyrus', 1),
#  ('Javon', 1),
#  ('James Michael', 1),
#  ('Freddie', 1),
#  ('Salvado', 1),
#  ('Matthew Ryan', 1),
#  ('Chacarion', 1),
#  ('Anthonie', 1),
#  ('Edward Foster', 1),
#  ('Mohammad Youssef', 1),
#  ('Saige', 1),
#  ('Pierre Gabriel', 1),
#  ('Albert Joseph', 1),
#  ('Jackie', 1),
#  ('Darrius', 1),
#  ('Jose Roman', 1),
#  ('David Wheat', 1),
#  ('Kevin Thomas', 1),
#  ('Darren Billy', 1),
#  ('Andre Dontrell', 1),
#  ('Dontae L.', 1),
#  ('Robbie Lee', 1),
#  ('Tamala', 1),
#  ('Seth', 1),
#  ('Lee Aaron', 1),
#  ('Bryan Keith', 1),
#  ('Khari', 1),
#  ('Jean Paul', 1),
#  ('Roger Darrin', 1),
#  ('Ryan Daniel', 1),
#  ('Oscar Lotari', 1),
#  ('Virgil', 1),
#  ('Franklin', 1),
#  ('Daniel Robert', 1),
#  ('Darius D.', 1),
#  ('Tyler Alexander', 1),
#  ('Keshawn Dominique', 1),
#  ('Vincente', 1),
#  ('Abel', 1),
#  ('Tsombe', 1),
#  ('Derrick Lee', 1),
#  ('Roderick', 1),
#  ('Shamir Terrel', 1),
#  ('Jeffrey Clyde', 1),
#  ('Robert Patrick', 1),
#  ('Edrian', 1),
#  ('Richard Tyler', 1),
#  ('Casey George', 1),
#  ('Randall Lance', 1),
#  ('Richard Dean Shull', 1),
#  ('Nathaniel', 1),
#  ('Redel', 1),
#  ('Anthony Lorenzo', 1),
#  ('Garland', 1),
#  ('Hector Rene Sorriano', 1),
#  ('Asshams Pharoah', 1),
#  ('Allen Matthew', 1),
#  ('Benjamin Peter', 1),
#  ('Jonathon', 1),
#  ('Steven B.', 1),
#  ('Mansur', 1),
#  ('Deviere Ernel', 1),
#  ('Wade Allen', 1),
#  ('Jeffory Ray', 1),
#  ('Timmy', 1),
#  ('Charles S.', 1),
#  ('Alan Joseph', 1),
#  ('Kenneth Henry', 1),
#  ('Richard Francis', 1),
#  ('Christopher Ray', 1),
#  ('Julian', 1),
#  ('Bobby Troledge', 1),
#  ('William Lee', 1),
#  ('Curtis', 1),
#  ('Bertrand', 1),
#  ('Yonas', 1),
#  ('Felix', 1),
#  ('Devin Brian', 1),
#  ('James Marcus', 1),
#  ('Rafael Cruz', 1),
#  ('Cedric Maurice', 1),
#  ('Charles Robert', 1),
#  ('Michael Todd', 1),
#  ('Jose Ramon Damiani', 1),
#  ('Richard Keith', 1),
#  ('Sully', 1),
#  ('Harrison', 1),
#  ("La'vante Trevon", 1),
#  ('Angelo Delano', 1),
#  ('Casimero Carlos', 1),
#  ('Vincent J.', 1),
#  ('Tian', 1),
#  ('Austin Wilburly', 1),
#  ('Robert T.', 1),
#  ('Derick', 1),
#  ('Jack Stevens', 1),
#  ('Martin Francis', 1),
#  ('Jeffrey Eugene', 1),
#  ('Joseph Thompson', 1),
#  ('David Todd', 1),
#  ('Bobby R.', 1),
#  ('Rory Lynn', 1),
#  ('Nicholas Alan', 1),
#  ('Lucien', 1),
#  ('Michael Thomas', 1),
#  ('Jerrald', 1),
#  ('Joel Dixon', 1),
#  ('Tim Kyle', 1),
#  ('Donaven Kyle', 1),
#  ('Keith Harrison', 1),
#  ('Kenneth Ray', 1),
#  ('Ernesto Medina', 1),
#  ('Norma Angelica', 1),
#  ('Victor Oswaldo', 1),
#  ('Junior', 1),
#  ('Alberto', 1),
#  ('Brandon Lamar', 1),
#  ('Phyllis Ilene', 1),
#  ('James Joseph', 1),
#  ('Jeffery', 1),
#  ('Charles A.', 1),
#  ('Donald Miller', 1),
#  ('Amado', 1),
#  ('Gary Carmona', 1),
#  ('Margaret', 1),
#  ('Joe Pasquez', 1),
#  ('Bernard Brandon', 1),
#  ('Robert Humberto', 1),
#  ('Rudolph', 1),
#  ('Michelle Marie', 1),
#  ('Michael Donald', 1),
#  ('Jorge Santiago', 1),
#  ('Linda Lee', 1),
#  ('Michael J.', 1),
#  ('Martin Ryans', 1),
#  ('Johnny Angel', 1),
#  ('Ricky Javenta', 1),
#  ('Gino', 1),
#  ('Dequan', 1),
#  ('Krikor', 1),
#  ('Dion Lamont', 1),
#  ('Roger D.', 1),
#  ('Lamontez', 1),
#  ('Darien', 1),
#  ('Jonathan Tyler', 1),
#  ('Miguel Angel Marin', 1),
#  ('Ryan Christopher', 1),
#  ('Adriene Jamarr', 1),
#  ('Stephen H.', 1),
#  ('Rolly', 1),
#  ('Darren Myron', 1),
#  ('Jon', 1),
#  ('John Harley', 1),
#  ('Marquesha', 1),
#  ('Kobvey', 1),
#  ('Tyrie', 1),
#  ('Ricky Keith', 1),
#  ('Jerry Michael Graham', 1),
#  ('Jasper Levi', 1),
#  ('Deaunte Lamar', 1),
#  ('Allen Quintez', 1),
#  ('Floyd Ray', 1),
#  ('Noah', 1),
#  ('Bennie Lee', 1),
#  ('Luverne Roy', 1),
#  ('Killian', 1),
#  ('Faisal', 1),
#  ('Timothy Gene', 1),
#  ('Laura', 1),
#  ('James Francis', 1),
#  ('Kim Lee', 1),
#  ('Delvin', 1),
#  ('Dale Maverick', 1),
#  ('Leonel', 1),
#  ('Dana Bruce', 1),
#  ('Eddie Gabriel', 1),
#  ('Jason Leanard', 1),
#  ('Javier Lopez', 1),
#  ('Ryan Quinn', 1),
#  ('John David', 1),
#  ('Jamar', 1),
#  ('Cameron Davis', 1),
#  ('Yohans', 1),
#  ('Jeray', 1),
#  ('Derry', 1),
#  ('Cornelius', 1),
#  ('Randy Allen', 1),
#  ('Darick', 1),
#  ('Nathaniel Harris', 1),
#  ('Thomas Joseph', 1),
#  ('Magnum Edgar', 1),
#  ('Douglas R.', 1),
#  ('Somer', 1),
#  ('Rick', 1),
#  ('Justin D.', 1),
#  ('Hugo Fernando', 1),
#  ('Tuan', 1),
#  ('John Anthony', 1),
#  ('Tashfeen', 1),
#  ('Syed', 1),
#  ('Allen', 1),
#  ('Neil Scott', 1),
#  ('Raymone M.', 1),
#  ('Colten Price', 1),
#  ('Sheilah', 1),
#  ('Carlumandarlo', 1),
#  ('Sammy Monroe', 1),
#  ('Thomas Arthur', 1),
#  ('Javario Shante', 1),
#  ('Andrew Jospeh', 1),
#  ('Shirley', 1),
#  ('Enrique', 1),
#  ('Jeffrey Gene', 1),
#  ('Brenda Dean', 1),
#  ('Mharloun Verdejo', 1),
#  ('Ronnie Dubose', 1),
#  ('Bryant Neil', 1),
#  ('Erica', 1),
#  ('Amos', 1),
#  ('Trayvon', 1),
#  ('Ruben Jose', 1),
#  ('Chan', 1),
#  ('Schuylar', 1),
#  ('Terrozza Tyree', 1),
#  ('Bettie', 1),
#  ('Quintonio', 1),
#  ('Gayneaux Paul', 1),
#  ('Corey Jason', 1),
#  ('Siolosega', 1),
#  ('Tien', 1),
#  ('John Randell', 1),
#  ('Lance', 1),
#  ('Lonnie Haskell', 1),
#  ('Germonta', 1),
#  ('Joel Anthony', 1),
#  ('James K.', 1),
#  ('Carlton Antonio', 1),
#  ('Alan Huberth', 1),
#  ('Andrew Earl', 1),
#  ('Christine A.', 1),
#  ('Alan Paul', 1),
#  ('Ramone', 1),
#  ('Ciara', 1),
#  ('William Keith', 1),
#  ('Rakeem', 1),
#  ('Ashton Lane', 1),
#  ('Kelsey Rose', 1),
#  ('Crayton', 1),
#  ('Joshua Tate', 1),
#  ('Corey Lee', 1),
#  ('Levi Gene', 1),
#  ('Vasilios Alexander', 1),
#  ('Gary Wayne', 1),
#  ('Jim', 1),
#  ('Randy Joe', 1),
#  ('Michael Clyde', 1),
#  ('Michael Lamar', 1),
#  ('Robert "LaVoy"', 1),
#  ('Thongsavanh', 1),
#  ('Janet', 1),
#  ('Nathan Lee', 1),
#  ('Israel Vladimir', 1),
#  ('Jacqueline D.', 1),
#  ('Randolph', 1),
#  ('Angela', 1),
#  ('Charles M.', 1),
#  ('Philip B.', 1),
#  ('Jeremy J.', 1),
#  ('Joshua Shane', 1),
#  ('Juan A.', 1),
#  ('Jeffry', 1),
#  ('Edgar Rene', 1),
#  ('John Henry', 1),
#  ('Cristiaan Oliver', 1),
#  ('Kayden', 1),
#  ('Antronie', 1),
#  ('Blake Edward', 1),
#  ('Vinson Ray', 1),
#  ('Marese V.', 1),
#  ('Shalamar', 1),
#  ('Scottie', 1),
#  ('David Brian', 1),
#  ('Alijah', 1),
#  ('David Glen', 1),
#  ('Sahlah', 1),
#  ('Ali Eisa Abdalla', 1),
#  ('Calin', 1),
#  ('Dyzhawn L.', 1),
#  ('Rammy', 1),
#  ('Marc', 1),
#  ('Brandon Lee', 1),
#  ('Destry', 1),
#  ('Shawn Henry Allen', 1),
#  ('Justin Patrick', 1),
#  ('Edgar', 1),
#  ('Marcos', 1),
#  ('Charles Lee', 1),
#  ('Che', 1),
#  ('Sherrisa', 1),
#  ('Marquintan', 1),
#  ('Patricia', 1),
#  ('Gerardino Cayetano', 1),
#  ('Jamie Clark', 1),
#  ('Rouven', 1),
#  ('Angel Alan', 1),
#  ('Baltazar', 1),
#  ('Alex', 1),
#  ('Christopher J.', 1),
#  ('Kionte Desean', 1),
#  ('Abraham Mitchell', 1),
#  ('Akiel', 1),
#  ('Dimitri', 1),
#  ('Jorge Brian', 1),
#  ('Mickey Dewayne', 1),
#  ('Travis Boyd', 1),
#  ('Osvaldo', 1),
#  ('Bryon', 1),
#  ('Randall J.', 1),
#  ('John Charles "JC"', 1),
#  ('Daniel H.', 1),
#  ('Jeffrey Glen', 1),
#  ('Wesley', 1),
#  ('Arteair Porter', 1),
#  ('German', 1),
#  ('Manford "Butch" Moore', 1),
#  ('Teodoro', 1),
#  ('Gevork', 1),
#  ('Jose Raul', 1),
#  ('Wesley Chad', 1),
#  ('Keith Montgomery', 1),
#  ('Amy Jean', 1),
#  ('Jacai', 1),
#  ('Lamar', 1),
#  ('Daniel J.', 1),
#  ('Ed Russell', 1),
#  ('Cristian Rene', 1),
#  ('Map', 1),
#  ('Sunny', 1),
#  ('David Alma', 1),
#  ('Thurman', 1),
#  ('Dylan R.', 1),
#  ('Boyd Keith', 1),
#  ('Ralph "Phil"', 1),
#  ('Edward J.', 1),
#  ('Ethan James', 1),
#  ('Travis J.', 1),
#  ('Daven Scott', 1),
#  ('Alexio', 1),
#  ('Dominique', 1),
#  ('Joel A.', 1),
#  ('Jermon', 1),
#  ('Terrence Shane', 1),
#  ('Donald Andrew', 1),
#  ('Patrick Matthew', 1),
#  ('Loreal', 1),
#  ('Robert D.', 1),
#  ('Deriante Deon', 1),
#  ('Joseph Louis', 1),
#  ('Robert Morgan Garrison', 1),
#  ('Denise', 1),
#  ('James Craig', 1),
#  ('Kimani', 1),
#  ('Matthew Vincent', 1),
#  ('James Brown', 1),
#  ('Preston Paul', 1),
#  ('Darrin Andrew', 1),
#  ('Raul Salvador Marquez', 1),
#  ('Laronda', 1),
#  ('Lance C.', 1),
#  ('Dazion', 1),
#  ('Melissa M.', 1),
#  ('Lamont', 1),
#  ('Diahlo', 1),
#  ('Quron', 1),
#  ('Arturo Yobani-Torrez', 1),
#  ('Efren Eloy', 1),
#  ('Pierre', 1),
#  ('Dion', 1),
#  ('Jeffrey Gray', 1),
#  ('Koltlee', 1),
#  ('Clemente', 1),
#  ('Storm Allen', 1),
#  ('Gerald Robert', 1),
#  ('Richard Bard', 1),
#  ('Edson', 1),
#  ('Rico Don Rae', 1),
#  ('Sylasone', 1),
#  ('Jorevis', 1),
#  ('Daniel Eric', 1),
#  ('Francis Scot', 1),
#  ('Jackie Lee', 1),
#  ('Mario Mejia', 1),
#  ('Demarcus', 1),
#  ('Mitchell', 1),
#  ('Jakob E.', 1),
#  ('Kay Frances', 1),
#  ('Jacquelyn', 1),
#  ('Darrel S.', 1),
#  ('David Shane', 1),
#  ('Cin Lam', 1),
#  ('Kendar del', 1),
#  ('Lee', 1),
#  ('Ashtian', 1),
#  ('Jeffrey Darrell', 1),
#  ('Oswald', 1),
#  ('Bender', 1),
#  ('Marion', 1),
#  ('Charlin', 1),
#  ('Reginald Darnell', 1),
#  ('Cayce A.', 1),
#  ('Gerry J.', 1),
#  ('Burt', 1),
#  ('Deresha', 1),
#  ('Ronald D.', 1),
#  ('Nathan Q.', 1),
#  ('Alton Fitzgerald', 1),
#  ('Derek J.', 1),
#  ('Arthur R.', 1),
#  ('Jaffort', 1),
#  ('Thongsoune', 1),
#  ('Robert Mark', 1),
#  ('Dracy "Clint"', 1),
#  ('Jabril', 1),
#  ('Garry', 1),
#  ('Israel', 1),
#  ('Jeremias', 1),
#  ('Jaime', 1),
#  ('Timothy Brandon', 1),
#  ('Kentrill William', 1),
#  ('Michael Eugene Wilson', 1),
#  ('Vernell', 1),
#  ('Bryson', 1),
#  ('Verl', 1),
#  ('Bodhi Wilson Dean', 1),
#  ('Doll', 1),
#  ('Eugene "Geno" Francis', 1),
#  ('Warren', 1),
#  ('Devonte', 1),
#  ('Tk', 1),
#  ('Angel Daniel', 1),
#  ('Dionisio Augustine Garza', 1),
#  ('Donald Edward Brown', 1),
#  ('John Mark', 1),
#  ('Todd Brent', 1),
#  ('Osee', 1),
#  ('Willie Demetrius', 1),
#  ('Rodney Rodriguez', 1),
#  ('Hubert Thomas Burns,', 1),
#  ('Daniel Jonathan', 1),
#  ('Demarco', 1),
#  ('Larry Dustin', 1),
#  ('Kalyp Allen', 1),
#  ('Willis N.', 1),
#  ('William Michael', 1),
#  ('James Allen', 1),
#  ('John Michael', 1),
#  ('Clayton', 1),
#  ('J. Juan', 1),
#  ('Lyndarius Cortez', 1),
#  ('Daniel Bennett', 1),
#  ('Kenneth Allen', 1),
#  ('Noel', 1),
#  ('Mohammad', 1),
#  ('Fernando Geovanni', 1),
#  ('William Thomas', 1),
#  ('Sergey', 1),
#  ('Antwun', 1),
#  ('Rashaun', 1),
#  ('Raufeal M.', 1),
#  ('Devin Christopher', 1),
#  ('Lane', 1),
#  ('Josiah', 1),
#  ('Quencezola Maurice', 1),
#  ('Deravis Caine', 1),
#  ('Shaun Trevor', 1),
#  ('Jay', 1),
#  ('Ismael', 1),
#  ('Christy', 1),
#  ('Jamil Alejandro', 1),
#  ('Waldemar', 1),
#  ('Rodrigo', 1),
#  ('Terry Lynn', 1),
#  ('Germichael', 1),
#  ('Donte L.', 1),
#  ('Sherman', 1),
#  ('Blake', 1),
#  ('Walden', 1),
#  ('Jessie J.', 1),
#  ('Lafayette', 1),
#  ('Michael William', 1),
#  ...]

# %%
x,y = zip(*sorted(most,key=lambda x :x[1]))

# %%
fig,ax=plt.subplots(figsize=(10,7))
ax.barh(x,y);

# %%
x,y = zip(*most)

# %%
x= pd.Series(x)
y = pd.Series(y)
fig, ax = plt.subplots(figsize=(20, 12))
ax.set_xticklabels(x, rotation=45)
sns.barplot(x,y)

ax.set_title("Most Common Name or Surname")
ax.set_xlabel("Name or Surname of Killed People",fontsize=15)
ax.set_ylabel('Frequency',fontsize=15)
ax.set_xticklabels(x, rotation=45);
# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()-.03, i.get_height()+.5, \
            str(i.get_height()), fontsize=15,
                color='dimgrey')

# %% [markdown]
# ## 3. Killed People According to Races (Pie Chart)

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
kill.race.unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
kill.race.value_counts()
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 242.7+ KB

# %% [markdown]
# Problem: missing value on race column.

# %% [markdown]
# **INSTRUCTION-1: Drop the all raws that contain missing value (dropna)**

# %%
kill.dropna(how ="all",inplace= True)

# %% [markdown]
# **INSTRUCTION-2: Demonstrate Race Ratio of Killed People by a Pie Chart**

# %%
fig1, ax1 = plt.subplots(figsize=(16,10))

ax1.pie(kill.race.value_counts(True),labels=['W', 'B', 'H', 'A', 'N', 'O'],autopct='%1.1f%%',colors=["grey","blue","red","yellow","green","brown"],pctdistance=0.6,
         startangle=5)
ax1.set_title("Kill People According to Races", color="b", fontsize=15)



plt.show();

# %% [markdown]
# ## 4a.Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x='gender',y ="age" ,data = kill,hue="manner_of_death");

# %% [markdown]
# ## 4b. Swarm Plot (Do not use in large datasets. The memory will not be enogh!)

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
sns.swarmplot(x='gender',y ="age" ,data = kill.head(1000),hue="manner_of_death");

# %% [markdown]
# ## 5. Kill properties (Count Plots)

# %% [markdown]
# **INSTRUCTION-1: Plot number of poeple by gender**

# %%
sns.countplot(x="gender", data=kill);

# %% [markdown]
# **INSTRUCTION-2: Plot 7 most common kill weapons**

# %%
k = kill.armed.value_counts().head(7)
a = pd.DataFrame(k)
a.index.name="weapon type"
a.rename(columns={"armed":"number of weapon"},inplace=True)
fig,ax=plt.subplots(figsize=(10,10))
ax.set_title("KİLL WEAPON",color="b")


sns.barplot(x=a.index,y = a["number of weapon"]);

# %% [markdown]
# **INSTRUCTION-3: Plot number of age of killed people under two groups : Under 25 and Above 25**

# %%
under25 = kill.age[kill.age<25].count()
under25
# Out:
# 450

# %%
above25 = kill.age[kill.age>25].count()
above25
# Out:
# 1905

# %%
d = {"number of people":[1905,450]}
k = pd.DataFrame(d) 
k=k.set_index([pd.Index(["above25","under25"])])
k
# Out:
#          number of people
# above25              1905
# under25               450

# %%
fig ,ax = plt.subplots(figsize = (10,7))
ax.set_title("Age of Killed People",color="b",fontsize=15)


sns.barplot(x=k.index,y =k["number of people"],data=k);
#sns.plot(above25,under25,data=k)

# %% [markdown]
# **INSTRUCTION-4: Plot number of killed poeple by race**

# %%
c =kill.race.value_counts()

# %%
x = pd.DataFrame(c)
x.index.name ="count"
#x.rename(columns={"race":"count"})
x
# Out:
#        race
# count
# W      1201
# B       618
# H       423
# A        39
# N        31
# O        28

# %%
fig ,ax = plt.subplots(figsize = (10,6))
ax.set_title("Race of Killed People",color="b",fontsize=15)


sns.countplot(kill.race);

# %% [markdown]
# **INSTRUCTION-5: Plot 12 most dangerous cities**

# %%
y =kill.city.value_counts().head(12)

# %%
t = pd.DataFrame(y)
t
# Out:
#               city
# Los Angeles     39
# Phoenix         31
# Houston         27
# Chicago         25
# Las Vegas       21
# San Antonio     20
# Columbus        19
# Austin          18
# Miami           18
# St. Louis       15
# Indianapolis    14
# Tucson          14

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_title("Most Dangerous Cities",color="b",fontsize=25)
ax.set_xticklabels(t.index, rotation=45)
sns.barplot(x= t.index,y = t.city);

# %% [markdown]
# **INSTRUCTION-6: Plot 20 most dangerous states**

# %%
p =kill.state.value_counts().head(20)

# %%
v = pd.DataFrame(p)
v
# Out:
#     state
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# WA     62
# IL     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.set_title("Most Dangerous States",color="b",fontsize="25")

ax.set_xticklabels(x.index, rotation=45)
sns.barplot(x= v.index,y = v.state);

# %% [markdown]
# **INSTRUCTION-7: Plot Having mental ilness or not for killed people**

# %%
sns.countplot(kill.signs_of_mental_illness)
plt.xlabel("Mental illness")
plt.title("Having mental illness or not", color="b", fontsize=15);

# %% [markdown]
# **INSTRUCTION-8: Plot number of Threat Types**

# %%
g = kill.threat_level.value_counts()
g
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
f = pd.DataFrame(g)
f.index.name ="threat types"
f.rename(columns=({"threat level":"count"}),inplace =True)
f
# Out:
#               threat_level
# threat types
# attack                1611
# other                  766
# undetermined           158

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.set_title("Threat Types",color="b",fontsize=15)

ax.set_xticklabels(x.index)
sns.barplot(x= f.index,y = f["threat_level"])

# %% [markdown]
# **INSTRUCTION-9: Plot number of Flee Types**

# %%
a=kill.flee.value_counts()
a
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
b = pd.DataFrame(a)
b.index.name ="Flee Types"
b.rename(columns={"flee":"count"},inplace = True)

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.set_title("Flee Types",color="b")

ax.set_xticklabels(x.index)
sns.barplot(x= b.index,y = b["count"]);
